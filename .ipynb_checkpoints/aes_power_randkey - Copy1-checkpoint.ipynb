# %%
'''
AES_Sbox：用來產生labels，256個值(16*16)
hw_list：漢明重量清單，256個值(16*16)
'''


import numpy as np
import os
import matplotlib.pyplot as plt

# The AES SBox that we will use to generate our labels
AES_Sbox = np.array([
            
            ])
# The Hamming weight list of each byte value
hw_list = np.array([
            0, 1, 1, 2, 1, 2, 2, 3, 1, 2, 2, 3, 2, 3, 3, 4, 1, 2, 2, 3, 2, 3, 3, 4, 2, 3, 3, 4, 3, 4, 4, 5,
            1, 2, 2, 3, 2, 3, 3, 4, 2, 3, 3, 4, 3, 4, 4, 5, 2, 3, 3, 4, 3, 4, 4, 5, 3, 4, 4, 5, 4, 5, 5, 6,
            1, 2, 2, 3, 2, 3, 3, 4, 2, 3, 3, 4, 3, 4, 4, 5, 2, 3, 3, 4, 3, 4, 4, 5, 3, 4, 4, 5, 4, 5, 5, 6,
            2, 3, 3, 4, 3, 4, 4, 5, 3, 4, 4, 5, 4, 5, 5, 6, 3, 4, 4, 5, 4, 5, 5, 6, 4, 5, 5, 6, 5, 6, 6, 7,
            1, 2, 2, 3, 2, 3, 3, 4, 2, 3, 3, 4, 3, 4, 4, 5, 2, 3, 3, 4, 3, 4, 4, 5, 3, 4, 4, 5, 4, 5, 5, 6,
            2, 3, 3, 4, 3, 4, 4, 5, 3, 4, 4, 5, 4, 5, 5, 6, 3, 4, 4, 5, 4, 5, 5, 6, 4, 5, 5, 6, 5, 6, 6, 7,
            2, 3, 3, 4, 3, 4, 4, 5, 3, 4, 4, 5, 4, 5, 5, 6, 3, 4, 4, 5, 4, 5, 5, 6, 4, 5, 5, 6, 5, 6, 6, 7,
            3, 4, 4, 5, 4, 5, 5, 6, 4, 5, 5, 6, 5, 6, 6, 7, 4, 5, 5, 6, 5, 6, 6, 7, 5, 6, 6, 7, 6, 7, 7, 8
            ])


# Load the joined trace file
data = np.load('aes_power_randkey.npz', allow_pickle=True)
t = data['traces']  #二維矩陣，裡面包含50000個矩陣，每t[n]裡有15000個數 <class 'numpy.float64'>
k = data['keys']   #二維矩陣，裡面包含50000個矩陣，每k[n]裡有16個數 <class 'numpy.uint8'>
p = data['plaintexts'] #二維矩陣，裡面包含50000個矩陣，每p[n]裡有16個數 <class 'numpy.uint8'>


plt.figure(figsize=(16, 9))
for i in range(4):
    plt.subplot(2, 2, i+1)
    plt.plot(t[i+100])    #選取trace裡第100~103筆資料，用15000個點做圖

plt.show()

# %%
hd_list = hw_list[AES_Sbox[k^p]]

# %%
listHDGP = {0:[], 1:[], 2:[], 3:[], 4:[], 5:[], 6:[], 7:[], 8:[]}
for i in range(len(hd_list[0])):          #16 
    for j in range(len(hd_list)):         #50000
            if hd_list[j][0] == i:
                listHDGP[i].append(t[j])

# %%
#取每組中，15000*n個的平均和變異數，存入GMean的值再每一個index會有15000個
meanlist = []
varlist = []
for i in range(0,9):
    meanlist.append(np.mean(listHDGP[i],axis = 0))
    varlist.append(np.var(listHDGP[i],axis = 0))

# %%
son2 = np.var(meanlist,axis = 0)  
mother2 = np.mean(varlist,axis = 0)

SNR2 = np.array(son2/mother2)

# %%
SNR = []
for i in range(0,15000):
    SNR.append(son[i]/mother[i])

# %%
plt.figure(figsize=(16, 9))
plt.plot( range(0,15000), SNR2)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.plot( range(0,15000), SNR)
plt.show()

# %%
[1,2,3][0]/[2,4,6][0]
# Out:
# 0.5

# %%
for i in range(0,9):
    np.mean(listHDGP[i])

# %%
print(listHDGP[5])

# %%
'''
檢測listHDGP總長度為50,000
sum = 0            
for i in range(len(listHDGP)):
    sum += len(listHDGP[i])
print(sum)
'''

#取每組中，15000*n個的平均和變異數，存入GMean的值再每一個index會有15000個
GMean = {0:[], 1:[], 2:[], 3:[], 4:[], 5:[], 6:[], 7:[], 8:[]}
GVar = {0:[], 1:[], 2:[], 3:[], 4:[], 5:[], 6:[], 7:[], 8:[]}
for i in range(0,9):
    for q in range(0,15000):
        sum = 0
        sum2 = 0
        for j in range(len(listHDGP[i])):
            sum += listHDGP[i][j][q]
            sum2 += listHDGP[i][j][q]**2
        mean = sum/j
        GMean[i].append(mean)            #15000個平均
        GVar[i].append(sum2/j-mean**2)

# %%
#SNR分子
son = []
sum = 0
sum2 = 0

for i in range(0,15000):
    for j in range(0,9):
        sum += GMean[j][i]
        sum2 += GMean[j][i]**2
    mean = sum/j
    son.append(sum2/j-mean**2)

#SNR分母
mother = []
sum = 0
for i in range(0,15000):
    for j in range(0,9):
        sum += GVar[j][i]
    mother.append(sum/j)
